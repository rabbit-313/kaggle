# %% [markdown]
# ## カラムの日本語訳

# %%
# Marital status - 配偶者の有無
# Application mode - 応募形態
# Application order - 応募順序
# Course - コース
# Daytime/evening attendance - 昼間/夜間の出席
# Previous qualification - 以前の資格
# Previous qualification (grade) - 以前の資格（成績）
# Nacionality - 国籍
# Mother's qualification - 母親の資格
# Father's qualification - 父親の資格
# Mother's occupation - 母親の職業
# Father's occupation - 父親の職業
# Admission grade - 入学成績
# Displaced - 移住者
# Educational special needs - 教育的特別支援
# Debtor - 債務者
# Tuition fees up to date - 授業料の支払い状況
# Gender - 性別
# Scholarship holder - 奨学生
# Age at enrollment - 入学時の年齢
# International - 国際的
# Curricular units 1st sem (credited) - 1学期の履修単位（認定済み）
# Curricular units 1st sem (enrolled) - 1学期の履修単位（登録済み）
# Curricular units 1st sem (evaluations) - 1学期の履修単位（評価済み）
# Curricular units 1st sem (approved) - 1学期の履修単位（合格済み）
# Curricular units 1st sem (grade) - 1学期の履修単位（成績）
# Curricular units 1st sem (without evaluations) - 1学期の履修単位（未評価）
# Curricular units 2nd sem (credited) - 2学期の履修単位（認定済み）
# Curricular units 2nd sem (enrolled) - 2学期の履修単位（登録済み）
# Curricular units 2nd sem (evaluations) - 2学期の履修単位（評価済み）
# Curricular units 2nd sem (approved) - 2学期の履修単位（合格済み）
# Curricular units 2nd sem (grade) - 2学期の履修単位（成績）
# Curricular units 2nd sem (without evaluations) - 2学期の履修単位（未評価）
# Unemployment rate - 失業率
# Inflation rate - インフレ率
# GDP - 国内総生産

# %% [markdown]
# ## import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
from lightgbm import LGBMClassifier
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from optuna.samplers import TPESampler
import optuna
import warnings
from sklearn.manifold import TSNE

# %% [markdown]
# ## データの読み込み

# %%
train = pd.read_csv("../inputs/train.csv")
test = pd.read_csv("../inputs/test.csv")

# %%
x_train = train.drop(columns=["Target", "id"], axis=1)
y_train = train["Target"]
x_test = test.drop(columns=["id"], axis=1)

# %%
le = LabelEncoder()
le.fit(y_train)
y_train = le.transform(y_train)

# %% [markdown]
# ## T-SNE２よる次元削減特徴量

# %%
features = x_train.columns
x_train_for_tsne = x_train.copy()
x_test_for_tsne = x_test.copy()

scaler = StandardScaler()
x_train_for_tsne = scaler.fit_transform(x_train_for_tsne)
x_test_for_tsne = scaler.transform(x_test_for_tsne)

tsne = TSNE(n_components=2, random_state=42)
train_tsne = tsne.fit_transform(x_train_for_tsne)
test_tsne = tsne.fit_transform(x_test_for_tsne)

# 新たな特徴量として追加
train_tsne_df = pd.DataFrame(train_tsne, columns=['tsne_1', 'tsne_2'])
test_tsne_df = pd.DataFrame(test_tsne, columns=['tsne_1', 'tsne_2'])

x_train = pd.concat([x_train, train_tsne_df], axis=1)
x_test = pd.concat([x_test, test_tsne_df], axis=1)

# %% [markdown]
# ## 特徴量エンジニアリング

# %%
age_labels = ['0', '1', '2', '3', '4', '5', '6']
age_bins = [0, 18, 25, 30, 40, 50, 60, 70]
def add_features(df):
    df["sum_grade"] = df["Curricular units 1st sem (grade)"] + df["Curricular units 2nd sem (grade)"]
    df["interaction_grade"] = df["Curricular units 1st sem (grade)"] * df["Curricular units 2nd sem (grade)"]
    df["average_grade"] = df["sum_grade"] / 2
    
    df["sum_approved"] = df["Curricular units 1st sem (approved)"] + df["Curricular units 2nd sem (approved)"]
    df["interaction_approved"] = df["Curricular units 1st sem (approved)"] * df["Curricular units 2nd sem (approved)"]
    df["average_approved"] = df["sum_approved"] / 2
    
    df['age_group'] = pd.cut(df['Age at enrollment'], bins=age_bins, labels=age_labels, right=True)

add_features(x_train)
add_features(x_test)

# %%
x_train
# Out:
#        Marital status  Application mode  Application order  Course  \
# 0                   1                 1                  1    9238
# 1                   1                17                  1    9238
# 2                   1                17                  2    9254
# 3                   1                 1                  3    9500
# 4                   1                 1                  2    9500
# ...               ...               ...                ...     ...
# 76513               1                17                  1    9254
# 76514               1                 1                  6    9254
# 76515               5                17                  1    9085
# 76516               1                 1                  3    9070
# 76517               1                 1                  1    9773
#
#        Daytime/evening attendance  Previous qualification  \
# 0                               1                       1
# 1                               1                       1
# 2                               1                       1
# 3                               1                       1
# 4                               1                       1
# ...                           ...                     ...
# 76513                           1                       1
# 76514                           1                       1
# 76515                           1                       1
# 76516                           1                       1
# 76517                           1                       1
#
#        Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                               126.0            1                       1
# 1                               125.0            1                      19
# 2                               137.0            1                       3
# 3                               131.0            1                      19
# 4                               132.0            1                      19
# ...                               ...          ...                     ...
# 76513                           121.0            1                      19
# 76514                           125.0            1                       1
# 76515                           138.0            1                      37
# 76516                           136.0            1                      38
# 76517                           133.1            1                      19
#
#        Father's qualification  ...   GDP      tsne_1     tsne_2  sum_grade  \
# 0                          19  ...  2.02  108.181633   1.579130  26.928571
# 1                          19  ...  2.02  -35.984982 -23.366604  11.600000
# 2                          19  ... -0.92  -71.786469  -5.816445   0.000000
# 3                           3  ...  2.02   97.711197 -45.690197  25.411250
# 4                          37  ...  0.32  -44.124130 -85.912933  25.866667
# ...                       ...  ...   ...         ...        ...        ...
# 76513                       1  ...  0.79   86.098816 -64.980354  21.266667
# 76514                      38  ... -3.12  -67.259239 -57.417076  26.875000
# 76515                      37  ... -3.12  -89.092697  74.283813  23.900000
# 76516                      37  ...  0.32  -87.191727  -4.385127   0.000000
# 76517                      19  ... -4.06   40.532909  37.499390  26.500000
#
#        interaction_grade  average_grade  sum_approved  interaction_approved  \
# 0             180.214286      13.464286            12                    36
# 1               0.000000       5.800000             4                     0
# 2               0.000000       0.000000             0                     0
# 3             161.419825      12.705625            14                    49
# 4             167.271111      12.933333            12                    36
# ...                  ...            ...           ...                   ...
# 76513         113.066667      10.633333            11                    30
# 76514         180.375000      13.437500            10                    24
# 76515         142.500000      11.950000             9                    20
# 76516           0.000000       0.000000             0                     0
# 76517         175.388889      13.250000            12                    36
#
#        average_approved  age_group
# 0                   6.0          0
# 1                   2.0          0
# 2                   0.0          0
# 3                   7.0          0
# 4                   6.0          0
# ...                 ...        ...
# 76513               5.5          0
# 76514               5.0          1
# 76515               4.5          1
# 76516               0.0          0
# 76517               6.0          1
#
# [76518 rows x 45 columns]

# %% [markdown]
# ## optunaによるチューニング

# %%
def objective(trial):
    params = {
        'num_leaves': trial.suggest_int('num_leaves', 100, 500),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 1.0, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 300, 1200),
        'subsample_for_bin': trial.suggest_int('subsample_for_bin', 20000, 300000),
        'min_child_samples': trial.suggest_int('min_child_samples', 20, 500),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-9, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-9, 10.0, log=True),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'subsample': trial.suggest_float('subsample', 0.25, 1.0),
        'max_depth': trial.suggest_int('max_depth', 1, 15)
    }
    
    model = LGBMClassifier(**params, objective='multiclass', random_state=0, device='cpu', verbosity=-1)
    
    # Cross-validation with 5 folds using KFold
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    cv_results = cross_val_score(model, x_train, y_train, cv=kf, scoring='accuracy')
    
    # We maximize accuracy, so we return the mean accuracy of the cross-validation
    return np.mean(cv_results)

study = optuna.create_study(sampler=TPESampler(n_startup_trials=30, multivariate=True, seed=0), direction="maximize")
study.optimize(objective, n_trials=100)
# Out:
# /home/ru/kaggle/venv/lib/python3.9/site-packages/optuna/samplers/_tpe/sampler.py:319: ExperimentalWarning: ``multivariate`` option is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2024-06-19 13:21:29,573] A new study created in memory with name: no-name-63086e16-f6d5-4487-886a-e8f7a8afa805
# [I 2024-06-19 13:21:46,095] Trial 0 finished with value: 0.8197156154513126 and parameters: {'num_leaves': 320, 'learning_rate': 0.269388301928541, 'n_estimators': 843, 'subsample_for_bin': 172567, 'min_child_samples': 223, 'reg_alpha': 0.0028770084050677926, 'reg_lambda': 2.3761404778025532e-05, 'colsample_bytree': 0.9350638004692479, 'subsample': 0.9727470703757719, 'max_depth': 6}. Best is trial 0 with value: 0.8197156154513126.
# [I 2024-06-19 13:23:18,245] Trial 1 finished with value: 0.8242896957670427 and parameters: {'num_leaves': 417, 'learning_rate': 0.11423254155608371, 'n_estimators': 811, 'subsample_for_bin': 279167, 'min_child_samples': 54, 'reg_alpha': 7.435205853060191e-09, 'reg_lambda': 1.5928833561691813e-09, 'colsample_bytree': 0.8995719073287628, 'subsample': 0.8336175632123879, 'max_depth': 14}. Best is trial 1 with value: 0.8242896957670427.
# [I 2024-06-19 13:23:41,244] Trial 2 finished with value: 0.8177814011643321 and parameters: {'num_leaves': 492, 'learning_rate': 0.39656750817710085, 'n_estimators': 715, 'subsample_for_bin': 238548, 'min_child_samples': 76, 'reg_alpha': 0.0025073225886269243, 'reg_lambda': 2.7135190452611042e-08, 'colsample_bytree': 0.9668013502297503, 'subsample': 0.6413862413125537, 'max_depth': 7}. Best is trial 1 with value: 0.8242896957670427.
# [I 2024-06-19 13:24:27,293] Trial 3 finished with value: 0.8223293505002743 and parameters: {'num_leaves': 206, 'learning_rate': 0.35356346291488117, 'n_estimators': 710, 'subsample_for_bin': 179162, 'min_child_samples': 29, 'reg_alpha': 0.0015009111045464082, 'reg_lambda': 0.0013211655088884039, 'colsample_bytree': 0.7701603981248542, 'subsample': 0.9578110588859681, 'max_depth': 11}. Best is trial 1 with value: 0.8242896957670427.
# [I 2024-06-19 13:24:51,795] Trial 4 finished with value: 0.8315167549973885 and parameters: {'num_leaves': 244, 'learning_rate': 0.07482796037620795, 'n_estimators': 928, 'subsample_for_bin': 36863, 'min_child_samples': 340, 'reg_alpha': 0.005086027407695681, 'reg_lambda': 1.270064013533415e-07, 'colsample_bytree': 0.477355778592912, 'subsample': 0.4865712631931379, 'max_depth': 6}. Best is trial 4 with value: 0.8315167549973885.
# [I 2024-06-19 13:25:15,823] Trial 5 finished with value: 0.8319872245051425 and parameters: {'num_leaves': 328, 'learning_rate': 0.07537078298264387, 'n_estimators': 1190, 'subsample_for_bin': 48572, 'min_child_samples': 120, 'reg_alpha': 4.1029401210349914e-08, 'reg_lambda': 0.003396903853102663, 'colsample_bytree': 0.5519749615238693, 'subsample': 0.5997330796422298, 'max_depth': 4}. Best is trial 5 with value: 0.8319872245051425.
# [I 2024-06-19 13:25:31,002] Trial 6 finished with value: 0.8264068149567958 and parameters: {'num_leaves': 163, 'learning_rate': 0.016624564693643644, 'n_estimators': 891, 'subsample_for_bin': 58691, 'min_child_samples': 114, 'reg_alpha': 4.866891972890967e-06, 'reg_lambda': 0.16215572955007182, 'colsample_bytree': 0.4582607654758368, 'subsample': 0.8784586806241029, 'max_depth': 2}. Best is trial 5 with value: 0.8319872245051425.
. Best is trial 7 with value: 0.8322224246727687.
# [I 2024-06-19 13:29:26,252] Trial 14 finished with value: 0.8281580560224843 and parameters: {'num_leaves': 459, 'learning_rate': 0.05434051375704854, 'n_estimators': 692, 'subsample_for_bin': 269739, 'min_child_samples': 407, 'reg_alpha': 0.01093668831711293, 'reg_lambda': 1.0052379437428308e-08, 'colsample_bytree': 0.9516895682468042, 'subsample': 0.7856809746618336, 'max_depth': 15}. Best is trial 7 with value: 0.8322224246727687.
# [I 2024-06-19 13:29:30,817] Trial 15 finished with value: 0.8316604928928415 and parameters: {'num_leaves': 159, 'learning_rate': 0.5448188369110731, 'n_estimators': 446, 'subsample_for_bin': 192357, 'min_child_samples': 79, 'reg_alpha': 0.3020524016657344, 'reg_lambda': 0.11835581143450927, 'colsample_bytree': 0.7414604431687559, 'subsample': 0.5553874729194997, 'max_depth': 2}. Best is trial 7 with value: 0.8322224246727687.
# [I 2024-06-19 13:29:44,499] Trial 16 finished with value: 0.8326667871122169 and parameters: {'num_leaves': 379, 'learning_rate': 0.08073937167660734, 'n_estimators': 950, 'subsample_for_bin': 262587, 'min_child_samples': 489, 'reg_alpha': 0.36143767833126167, 'reg_lambda': 1.3096065599990615e-09, 'colsample_bytree': 0.6159868386870183, 'subsample': 0.7974929218180435, 'max_depth': 3}. Best is trial 16 with value: 0.8326667871122169.
# [I 2024-06-19 13:29:48,129] Trial 17 finished with value: 0.8134817682978088 and parameters: {'num_leaves': 308, 'learning_rate': 0.012843280764272384, 'n_estimators': 480, 'subsample_for_bin': 25186, 'min_child_samples': 401, 'reg_alpha': 1.7347898824062586e-07, 'reg_lambda': 2.841298139605767e-06, 'colsample_bytree': 0.9568487760793545, 'subsample': 0.7783108014426496, 'max_depth': 1}. Best is trial 16 with value: 0.8326667871122169.
# [I 2024-06-19 13:30:02,618] Trial 18 finished with value: 0.827909742968991 and parameters: {'num_leaves': 166, 'learning_rate': 0.17496726491829132, 'n_estimators': 820, 'subsample_for_bin': 86610, 'min_child_samples': 469, 'reg_alpha': 0.0013793026152456194, 'reg_lambda': 0.00022715799683187434, 'colsample_bytree': 0.7539459858127426, 'subsample': 0.7975915221375772, 'max_depth': 5}. Best is trial 16 with value: 0.8326667871122169.
# [I 2024-06-19 13:30:19,300] Trial 19 finished with value: 0.8325753145922654 and parameters: {'num_leaves': 259, 'learning_rate': 0.02628376030296236, 'n_estimators': 467, 'subsample_for_bin': 284425, 'min_child_samples': 375, 'reg_alpha': 8.027643657785602e-05, 'reg_lambda': 1.8799499177898148e-07, 'colsample_bytree': 0.5526138890622357, 'subsample': 0.2935218702429067, 'max_depth': 7}. Best is trial 16 with value: 0.8326667871122169.
# [I 2024-06-19 13:31:13,971] Trial 20 finished with value: 0.8254005335471429 and parameters: {'num_leaves': 225, 'learning_rate': 0.24699432654084996, 'n_estimators': 640, 'subsample_for_bin': 70289, 'min_child_samples': 31, 'reg_alpha': 4.704314136881364e-09, 'reg_lambda': 0.006221967452909479, 'colsample_bytree': 0.6722181067336273, 'subsample': 0.6524344083315416, 'max_depth': 14}. Best is trial 16 with value: 0.8326667871122169.
# [I 2024-06-19 13:33:10,037] Trial 21 finished with value: 0.8284716841427148 and parameters: {'num_leaves': 497, 'learning_rate': 0.027151508837924436, 'n_estimators': 897, 'subsample_for_bin': 93730, 'min_child_samples': 29, 'reg_alpha': 0.03835186945091964, 'reg_lambda': 1.5855192098504768e-06, 'colsample_bytree': 0.6300783365031388, 'subsample': 0.6912378351652043, 'max_depth': 13}. Best is trial 16 with value: 0.8326667871122169.
# [I 2024-06-19 13
. Best is trial 30 with value: 0.8332679619038172.
# [I 2024-06-19 13:59:16,997] Trial 79 finished with value: 0.8203559598121772 and parameters: {'num_leaves': 469, 'learning_rate': 0.014841741038850918, 'n_estimators': 1184, 'subsample_for_bin': 44337, 'min_child_samples': 405, 'reg_alpha': 5.943547276876827e-05, 'reg_lambda': 2.7419797347489015e-05, 'colsample_bytree': 0.5270365173714039, 'subsample': 0.9371154570352784, 'max_depth': 1}. Best is trial 30 with value: 0.8332679619038172.
# [I 2024-06-19 13:59:27,891] Trial 80 finished with value: 0.8328759126628343 and parameters: {'num_leaves': 199, 'learning_rate': 0.052839887513473745, 'n_estimators': 359, 'subsample_for_bin': 153112, 'min_child_samples': 213, 'reg_alpha': 1.960620148296649e-08, 'reg_lambda': 2.149929671028632e-06, 'colsample_bytree': 0.42006397004612833, 'subsample': 0.31093471511278836, 'max_depth': 6}. Best is trial 30 with value: 0.8332679619038172.
# [I 2024-06-19 13:59:42,486] Trial 81 finished with value: 0.8288114859418079 and parameters: {'num_leaves': 399, 'learning_rate': 0.01105183731028941, 'n_estimators': 1111, 'subsample_for_bin': 148328, 'min_child_samples': 373, 'reg_alpha': 2.321226082317243e-06, 'reg_lambda': 6.693450684883759e-09, 'colsample_bytree': 0.7441739307179921, 'subsample': 0.7619416064960065, 'max_depth': 3}. Best is trial 30 with value: 0.8332679619038172.
# [I 2024-06-19 14:00:31,579] Trial 82 finished with value: 0.8307456985208255 and parameters: {'num_leaves': 424, 'learning_rate': 0.0268548811002478, 'n_estimators': 1098, 'subsample_for_bin': 29036, 'min_child_samples': 382, 'reg_alpha': 2.7197041245600087e-08, 'reg_lambda': 0.1110967750632142, 'colsample_bytree': 0.6304666633912827, 'subsample': 0.7423701653839669, 'max_depth': 12}. Best is trial 30 with value: 0.8332679619038172.
# [I 2024-06-19 14:00:43,743] Trial 83 finished with value: 0.8264590811862786 and parameters: {'num_leaves': 212, 'learning_rate': 0.013587964857729397, 'n_estimators': 1162, 'subsample_for_bin': 119871, 'min_child_samples': 323, 'reg_alpha': 0.004419246570781044, 'reg_lambda': 0.0033751165146170613, 'colsample_bytree': 0.6933781581982665, 'subsample': 0.8231520780756567, 'max_depth': 2}. Best is trial 30 with value: 0.8332679619038172.
# [I 2024-06-19 14:01:30,017] Trial 84 finished with value: 0.8328105608748924 and parameters: {'num_leaves': 351, 'learning_rate': 0.014141373196986023, 'n_estimators': 1183, 'subsample_for_bin': 51141, 'min_child_samples': 267, 'reg_alpha': 3.303015078399541e-09, 'reg_lambda': 1.7906573664536463, 'colsample_bytree': 0.5983121606783918, 'subsample': 0.4074608473790024, 'max_depth': 8}. Best is trial 30 with value: 0.8332679619038172.
# [I 2024-06-19 14:01:57,199] Trial 85 finished with value: 0.8329804553695777 and parameters: {'num_leaves': 111, 'learning_rate': 0.02810733815226854, 'n_estimators': 538, 'subsample_for_bin': 279387, 'min_child_samples': 435, 'reg_alpha': 2.0588382254296225e-06, 'reg_lambda': 0.00011036833583648335, 'colsample_bytree': 0.5380962185246777, 'subsample': 0.39932263143281066, 'max_depth': 12}. Best is trial 30 with value: 0.8332679619038172.
# [I 2024-06-19 14:02:14,834] Trial 86 finished with value: 0.8329804502456888 and parameters: {'num_leaves': 252, 'learning_rate': 0.041786902333848526, 'n_estimators': 396, 'subsample_for_bin': 231653, 'min_child_samples': 374, 'reg_alpha': 7.139297406040186e-07, 'reg_lambda': 5.6279208591915707e-08, 'colsample_bytree': 0.40476248120797353, 'subsample': 0.44903128374739987, 'max_depth': 10}. Best is trial 30 with value: 0.8332679619038172.
# [I 2024-06-19 14:02:50,022] Trial 87 finished with value: 0.8326667956520317 and parameters: {'num_leaves': 410, 'learning_rate': 0.011100731779782519, 'n_estimators': 1066, 'subsample_for_bin': 35085, 'min_child_samples': 498, 'reg_alpha': 8.702168517492573e-05, 'reg_lambda': 0.008488182790803815, 'colsample_bytree': 0.687730162128527, 'subsample': 0.7958716725454661, 'max_depth': 8}. Best is trial 30 with value: 0.8332679619038172.
# [I 2024-06-19 14:03:44,506] Trial 88 finished with value: 0.8334509342711278 and parameters: {'num_leaves': 254, 'learning_rate': 0.012341088279315678, 'n_estimators': 1150, 'subsample_for_bin': 112655, 'min_child_samples': 409, 'reg_alpha': 5.04266093431367e-07, 'reg_lambda': 0.01889696770827688, 'colsample_bytree': 0.4472356451830753, 'subsample': 0.5719969608388208, 'max_depth': 11}. Best is trial 88 with value: 0.8334509342711278.
# [I 2024-06-19 14:04:35,917] Trial 89 finished with value: 0.8330327250149864 and parameters: {'num_leaves': 219, 'learning_rate': 0.011728958920781544, 'n_estimators': 1145, 'subsample_for_bin': 90844, 'min_child_samples': 326, 'reg_alpha': 2.5835720762627755e-06, 'reg_lambda': 0.0002772297635047933, 'colsample_bytree': 0.5565254417149812, 'subsample': 0.654917090307822, 'max_depth': 9}. Best is trial 88 with value: 0.8334509342711278.
# [I 2024-06-19 14:05:16,217] Trial 90 finished with value: 0.8308240948761144 and parameters: {'num_leaves': 221, 'learning_rate': 0.04323441776346022, 'n_estimators': 1095, 'subsample_for_bin': 130087, 'min_child_samples': 395, 'reg_alpha': 1.7777185879081823e-07, 'reg_lambda': 0.015211040289220762, 'colsample_bytree': 0.4386730547610514, 'subsample': 0.4908654409332442, 'max_depth': 10}. Best is trial 88 with value: 0.8334509342711278.
# [I 2024-06-19 14:06:06,898] Trial 91 finished with value: 0.8308894441021117 and parameters: {'num_leaves': 263, 'learning_rate': 0.030856553796346737, 'n_estimators': 1172, 'subsample_for_bin': 154063, 'min_child_samples': 284, 'reg_alpha': 2.4584042960678566e-06, 'reg_lambda': 0.00031008311833632496, 'colsample_bytree': 0.6643103362350776, 'subsample': 0.6453061801457219, 'max_depth': 11}. Best is trial 88 with value: 0.8334509342711278.
# [I 2024-06-19 14:06:44,860] Trial 92 finished with value: 0.8329543201198826 and parameters: {'num_leaves': 218, 'learning_rate': 0.010408973112625002, 'n_estimators': 998, 'subsample_for_bin': 41487, 'min_child_samples': 235, 'reg_alpha': 3.832868462103856e-06, 'reg_lambda': 7.906991396347409e-05, 'colsample_bytree': 0.4928810728675862, 'subsample': 0.6318845101030274, 'max_depth': 7}. Best is trial 88 with value: 0.8334509342711278.
# [I 2024-06-19 14:06:59,201] Trial 93 finished with value: 0.8323531427663378 and parameters: {'num_leaves': 411, 'learning_rate': 0.17758522212103542, 'n_estimators': 785, 'subsample_for_bin': 289659, 'min_child_samples': 345, 'reg_alpha': 0.14837116008021173, 'reg_lambda': 1.1714159734406e-08, 'colsample_bytree': 0.46428161661249373, 'subsample': 0.6973595008382553, 'max_depth': 3}. Best is trial 88 with value: 0.8334509342711278.
# [I 2024-06-19 14:07:44,081] Trial 94 finished with value: 0.8332026186556905 and parameters: {'num_leaves': 286, 'learning_rate': 0.01008840664741738, 'n_estimators': 997, 'subsample_for_bin': 95664, 'min_child_samples': 438, 'reg_alpha': 0.00017446841412726584, 'reg_lambda': 0.11913850155199406, 'colsample_bytree': 0.42912383874949017, 'subsample': 0.5815779865082084, 'max_depth': 10}. Best is trial 88 with value: 0.8334509342711278.
# [I 2024-06-19 14:08:09,808] Trial 95 finished with value: 0.8332418112824552 and parameters: {'num_leaves': 259, 'learning_rate': 0.02984344217479542, 'n_estimators': 1108, 'subsample_for_bin': 95027, 'min_child_samples': 426, 'reg_alpha': 0.0005047975380991423, 'reg_lambda': 0.03158050342438329, 'colsample_bytree': 0.4016980672752418, 'subsample': 0.6958892093970477, 'max_depth': 5}. Best is trial 88 with value: 0.8334509342711278.
# [I 2024-06-19 14:09:03,368] Trial 96 finished with value: 0.8316735613716706 and parameters: {'num_leaves': 336, 'learning_rate': 0.021828365483746236, 'n_estimators': 1157, 'subsample_for_bin': 167042, 'min_child_samples': 487, 'reg_alpha': 5.999770196818032e-06, 'reg_lambda': 3.071806323726364, 'colsample_bytree': 0.4698553523543482, 'subsample': 0.36117175484278574, 'max_depth': 14}. Best is trial 88 with value: 0.8334509342711278.
# [I 2024-06-19 14:09:37,709] Trial 97 finished with value: 0.8297263178890096 and parameters: {'num_leaves': 298, 'learning_rate': 0.0646277318661116, 'n_estimators': 1137, 'subsample_for_bin': 142144, 'min_child_samples': 453, 'reg_alpha': 0.004103875790087873, 'reg_lambda': 0.0209748927718583, 'colsample_bytree': 0.4327877218425782, 'subsample': 0.7112490634471883, 'max_depth': 8}. Best is trial 88 with value: 0.8334509342711278.
# [I 2024-06-19 14:10:00,906] Trial 98 finished with value: 0.8329281694985206 and parameters: {'num_leaves': 176, 'learning_rate': 0.038629026287802196, 'n_estimators': 942, 'subsample_for_bin': 95715, 'min_child_samples': 384, 'reg_alpha': 2.9560636983138077e-06, 'reg_lambda': 0.2921894886863954, 'colsample_bytree': 0.4157295671210355, 'subsample': 0.7574014191229165, 'max_depth': 6}. Best is trial 88 with value: 0.8334509342711278.
# [I 2024-06-19 14:10:32,925] Trial 99 finished with value: 0.8333986552319226 and parameters: {'num_leaves': 345, 'learning_rate': 0.018633568912523893, 'n_estimators': 871, 'subsample_for_bin': 188067, 'min_child_samples': 446, 'reg_alpha': 1.357597662304883e-05, 'reg_lambda': 0.6027916808117609, 'colsample_bytree': 0.5129865130023343, 'subsample': 0.66905727045911, 'max_depth': 8}. Best is trial 88 with value: 0.8334509342711278.

# %% [markdown]
# ## optunaによるチューニングパラメータを利用してモデルを作成

# %%
# params = {'num_leaves': 489, 'learning_rate': 0.012116445295938309, 'n_estimators': 826, 'subsample_for_bin': 99575, 'min_child_samples': 375, 'reg_alpha': 0.0009319658505052182, 'reg_lambda': 9.808198625785853e-05, 'colsample_bytree': 0.49847769193736885, 'subsample': 0.9517501312160254, 'max_depth': 15}

lgb_model = LGBMClassifier(**study.best_params, objective='multiclass', random_state=0, device='cpu', verbosity=-1)
print('Best value:', study.best_value)
print('Best trial:', study.best_trial.params)
# Out:
# Best value: 0.8334509342711278
# Best trial: {'num_leaves': 254, 'learning_rate': 0.012341088279315678, 'n_estimators': 1150, 'subsample_for_bin': 112655, 'min_child_samples': 409, 'reg_alpha': 5.04266093431367e-07, 'reg_lambda': 0.01889696770827688, 'colsample_bytree': 0.4472356451830753, 'subsample': 0.5719969608388208, 'max_depth': 11}

# %% [markdown]
# ## クロスバリデーション

# %%
cv = KFold(5, shuffle=True, random_state=42)
cv_splits = tqdm(cv.split(x_train, y_train), total=cv.get_n_splits(), desc='CV Progress')

scores = []
for train_idx, val_idx in cv_splits:
    x_train_fold, x_val_fold = x_train.iloc[train_idx], x_train.iloc[val_idx]
    y_train_fold, y_val_fold = y_train[train_idx], y_train[val_idx]
    lgb_model.fit(x_train_fold, y_train_fold)
    y_pred = lgb_model.predict(x_val_fold)
    r2 = accuracy_score(y_val_fold, y_pred)
    scores.append(r2)
    
    print(f'score: {r2}')

print(f"Mean Score: {np.mean(scores):.5f}")
# Out:
# CV Progress:  20%|██        | 1/5 [00:10<00:43, 10.86s/it]
# score: 0.8351411395713539
# CV Progress:  40%|████      | 2/5 [00:21<00:32, 10.89s/it]
# score: 0.8380162049137481
# CV Progress:  60%|██████    | 3/5 [00:32<00:21, 10.94s/it]
# score: 0.8286069001568217
# CV Progress:  80%|████████  | 4/5 [00:43<00:10, 10.84s/it]
# score: 0.8309481800954062
# CV Progress: 100%|██████████| 5/5 [00:54<00:00, 10.83s/it]
# score: 0.8345422466183101
# Mean Score: 0.83345

# %%
from sklearn import datasets

feature_name = x_train.columns
importance = pd.DataFrame(lgb_model.feature_importances_, columns=['importance'], index=feature_name)
display(importance.sort_values('importance', ascending=False))
# Out:
#                                                 importance
# Admission grade                                      20198
# tsne_2                                               18730
# tsne_1                                               18232
# Previous qualification (grade)                       13588
# Curricular units 2nd sem (grade)                     12695
# Curricular units 1st sem (grade)                     11878
# Course                                               11227
# sum_grade                                            11085
# interaction_grade                                    10329
# Age at enrollment                                     9127
# Father's occupation                                   8469
# Curricular units 2nd sem (evaluations)                7757
# Unemployment rate                                     7100
# Curricular units 1st sem (evaluations)                7015
# interaction_approved                                  6771
# Mother's occupation                                   6603
# GDP                                                   6111
# Mother's qualification                                6017
# average_grade                                         5576
# Application mode                                      5449
# Father's qualification                                5442
# Inflation rate                                        5406
# sum_approved                                          5049
# Curricular units 2nd sem (approved)                   4512
# Curricular units 2nd sem (enrolled)                   3837
# Curricular units 1st sem (enrolled)                   3620
# Curricular units 1st sem (approved)                   3217
# Application order                                     2918
# average_approved                                      2403
# Gender                                                2267
# Displaced                                             2119
# Scholarship holder                                    1941
# age_group                                             1768
# Tuition fees up to date                               1371
# Previous qualification                                1098
# Debtor                                                 823
# Curricular units 1st sem (credited)                    741
# Curricular units 2nd sem (credited)                    720
# Marital status                                         431
# Daytime/evening attendance                             323
# Curricular units 1st sem (without evaluations)         274
# Curricular units 2nd sem (without evaluations)         222
# International                                            0
# Educational special needs                                0
# Nacionality                                              0

# %% [markdown]
# ## 提出用ファイルの作成

# %%
submit = pd.read_csv("../inputs/sample_submission.csv")
pred = lgb_model.predict(x_test)
submit['Target'] = le.inverse_transform(pred)
submit.to_csv("../outputs/submission_add_feature_tsne.csv", index=False)
submit.head()
# Out:
#       id    Target
# 0  76518   Dropout
# 1  76519  Graduate
# 2  76520  Graduate
# 3  76521  Graduate
# 4  76522  Enrolled
